# %%
import numpy as np
from numpy.linalg import norm
import pickle
from tqdm import tqdm, tqdm_notebook
import os
import time
from keras.preprocessing import image
from keras.applications.xception import Xception, preprocess_input

# %%
model = Xception(weights='imagenet', include_top=False,
                 input_shape=(224, 224, 3))
def extract_features(img_path, model):
    input_shape = (224, 224, 3)
    img = image.load_img(img_path, target_size=(
        input_shape[0], input_shape[1]))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    features = model.predict(preprocessed_img)
    flattened_features = features.flatten()
    normalized_features = flattened_features / norm(flattened_features)
    return normalized_features

# %%
features = extract_features('google_image_search/mslogo1.jpeg', model)
print(len(features))
# Out:
# 100352

# %%
extensions = ['.jpg', '.JPG', '.jpeg', '.JPEG', '.png', '.PNG']
def get_file_list(root_dir):
    file_list = []
    counter = 1
    for root, directories, filenames in os.walk(root_dir):
        for filename in filenames:
            if any(ext in filename for ext in extensions):
                file_list.append(os.path.join(root, filename))
                counter += 1
    return file_list

# %%
# path to the datasets
root_dir = 'edge_detection/'
filenames = sorted(get_file_list(root_dir))
print(filenames)
# Out:
# ['edge_detection/10_horizontal.png', 'edge_detection/10_vertical.png', 'edge_detection/11_horizontal.png', 'edge_detection/11_vertical.png', 'edge_detection/12_horizontal.png', 'edge_detection/12_vertical.png', 'edge_detection/13_horizontal.png', 'edge_detection/13_vertical.png', 'edge_detection/14_horizontal.png', 'edge_detection/14_vertical.png', 'edge_detection/24_vertical.png', 'edge_detection/25_horizontal.png', 'edge_detection/25_vertical.png', 'edge_detection/26_horizontal.png', 'edge_detection/26_vertical.png', 'edge_detection/27_horizontal.png', 'edge_detection/27_vertical.png', 'edge_detection/28_horizontal.png', 'edge_detection/28_vertical.png', 'edge_detection/29_horizontal.png', 'edge_detection/29_vertical.png', 'edge_detection/2_horizontal.png', 'edge_detection/2_vertical.png', 'edge_detection/30_horizontal.png', 'edge_detection/30_vertical.png', 'edge_detection/31_horizontal.png', 'edge_detection/31_vertical.png', 'edge_detection/32_horizontal.png', 'edge_detection/32_vertical.png', 'edge_detection/33_horizontal.png', 'edge_detection/33_vertical.png', 'edge_detection/34_horizontal.png', 'edge_detection/34_vertical.png', 'edge_detection/35_horizontal.png', 'edge_detection/35_vertical.png', 'edge_detection/36_horizontal.png', 'edge_detection/36_vertical.png', 'edge_detection/37_horizontal.png', 'edge_detection/37_vertical.png', 'edge_detection/38_horizontal.png', 'edge_detection/38_vertical.png', 'edge_detection/3_horizontal.png', 'edge_detection/3_vertical.png', 'edge_detection/40_horizontal.png', 'edge_detection/40_vertical.png', 'edge_detection/41_horizontal.png', 'edge_detection/41_vertical.png', 'edge_detection/43_horizontal.png', 'edge_detection/43_vertical.png', 'edge_detection/44_horizontal.png', 'edge_detection/44_vertical.png', 'edge_detection/45_horizontal.png', 'edge_detection/45_vertical.png', 'edge_detection/48_vertical.png', 'edge_detection/49_horizontal.png', 'edge_detection/49_vertical.png', 'edge_detection/4_horizontal.png', 'edge_detection/4_vertical.png', 'edge_detection/50_horizontal.png', 'edge_detection/50_vertical.png', 'edge_detection/51_horizontal.png', 'edge_detection/51_vertical.png', 'edge_detection/53_horizontal.png', 'edge_detection/53_vertical.png', 'edge_detection/55_horizontal.png', 'edge_detection/55_vertical.png', 'edge_detection/56_horizontal.png', 'edge_detection/56_vertical.png', 'edge_detection/57_horizontal.png', 'edge_detection/57_vertical.png', 'edge_detection/58_horizontal.png', 'edge_detection/58_vertical.png', 'edge_detection/5_horizontal.png', 'edge_detection/5_vertical.png', 'edge_detection/60_horizontal.png', 'edge_detection/60_vertical.png', 'edge_detection/61_horizontal.png', 'edge_detection/61_vertical.png', 'edge_detection/62_horizontal.png', 'edge_detection/62_vertical.png', 'edge_detection/63_horizontal.png', 'edge_detection/63_vertical.png', 'edge_detection/64_horizontal.png', 'edge_detection/64_vertical.png', 'edge_detection/65_horizontal.png', 'edge_detection/65_vertical.png', 'edge_detection/66_horizontal.png', 'edge_detection/66_vertical.png', 'edge_detection/67_horizontal.png', 'edge_detection/67_vertical.png', 'edge_detection/68_horizontal.png', 'edge_detection/68_vertical.png', 'edge_detection/69_horizontal.png', 'edge_detection/69_vertical.png', 'edge_detection/6_horizontal.png', 'edge_detection/6_vertical.png', 'edge_detection/71_horizontal.png', 'edge_detection/71_vertical.png', 'edge_detection/72_horizontal.png', 'edge_detection/72_vertical.png', 'edge_detection/73_horizontal.png', 'edge_detection/73_vertical.png', 'edge_detection/7_horizontal.png', 'edge_detection/7_vertical.png', 'edge_detection/8_horizontal.png', 'edge_detection/8_vertical.png', 'edge_detection/9_horizontal.png', 'edge_detection/9_vertical.png']

# %%
feature_list = []
for i in tqdm_notebook(range(len(filenames))):
    feature_list.append(extract_features(filenames[i], model))
# Out:
# <ipython-input-77-21d73bc1ed80>:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(filenames))):
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=108.0), HTML(value='')))

# %%
pickle.dump(feature_list, open('google_image_search/data/features-mslogo-Xception.pickle', 'wb'))
pickle.dump(filenames, open('google_image_search/data/filenames-mslogo.pickle','wb'))

# %%
## Similarity search

feature_list = pickle.load(open('google_image_search/data/features-mslogo-Xception.pickle', 'rb'))
filenames = pickle.load(open('google_image_search/data/filenames-mslogo.pickle', 'rb'))

# %%
len(filenames)
# Out:
# 108

# %%
len(feature_list)
# Out:
# 108

# %%
from sklearn.neighbors import NearestNeighbors
neighbors = NearestNeighbors(n_neighbors=5, algorithm='auto').fit(feature_list)
distances, indices = neighbors.kneighbors([feature_list[-3]])

# %%
print(distances)
print(indices)
print(indices.shape)
# Out:
# [[0.         0.82923296 0.86824733 0.87989256 0.92770061]]
# [[105 103 104  34  55]]
# (1, 5)

# %%
plt.imshow(mpimg.imread(filenames[indices[0][0]]))

# %%
def process(i):
#     print(i)
#     plt.imshow(mpimg.imread(filenames[indices[0][i]]))
    filename = filenames[indices[0][i]]
    image = mpimg.imread(filename)
    # <something gets done here>
    plt.figure()
    plt.title('{}'.format(distances[0][i]))
    plt.imshow(image)

for i in range(0,indices.shape[1]): 
    process(i)

# %%
distances, indices = neighbors.kneighbors([feature_list[6]])

# %%
def process(i):
#     print(i)
#     plt.imshow(mpimg.imread(filenames[indices[0][i]]))
    filename = filenames[indices[0][i]]
    image = mpimg.imread(filename)
    # <something gets done here>
    plt.figure()
    plt.title('{} {}'.format(filename,distances[0][i]))
    plt.imshow(image)

for i in range(0,indices.shape[1]): 
    process(i)

# %%
distances, indices = neighbors.kneighbors([feature_list[6]])

# %%
for i in range(0,indices.shape[1]): 
    process(i)

# %% [markdown]
# ## For Xbox Logo

# %%
filenames[-24]
# Out:
# 'edge_detection/65_horizontal.png'

# %%
distances, indices = neighbors.kneighbors([feature_list[-24]])

# %%
for i in range(0,indices.shape[1]): 
    process(i)

# %%
distances, indices = neighbors.kneighbors([feature_list[-25]])

# %%
for i in range(0,indices.shape[1]): 
    process(i)

# %%
filenames
# Out:
# ['google_image_search/mslogo1.jpeg',
#  'google_image_search/mslogo1_180degree_rotation copy.jpeg',
#  'google_image_search/mslogo1_90degree_rotation.jpeg',
#  'google_image_search/mslogo2.png',
#  'google_image_search/mslogo3.png',
#  'google_image_search/mslogo4.jpeg',
#  'google_image_search/mslogo5.jpeg',
#  'google_image_search/mslogo6.jpeg',
#  'google_image_search/mslogo7.jpeg',
#  'google_image_search/mslogo8.png',
#  'google_image_search/mslogo9.png']

# %%
plt.imshow(mpimg.imread(filenames[indices[0][2]]))

# %%
plt.imshow(mpimg.imread(filenames[indices[0][3]]))

# %%
plt.imshow(mpimg.imread(filenames[indices[0][4]]))

# %%
plt.imshow(mpimg.imread(filenames[indices[0][5]]))

# %%
plt.imshow(mpimg.imread(filenames[indices[0][6]]))

# %%
plt.imshow(mpimg.imread(filenames[indices[0][7]]))

# %%
plt.imshow(mpimg.imread(filenames[indices[0][8]]))

# %%
def plot_images(similar_image_paths,distances):
    # Show subplots | shape: (1,3) 
        fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(12,4))
        for i, ax in enumerate(axs.flatten()):
            plt.sca(ax)
            plt.imshow(mpimg.imread(similar_image_paths[i]), cmap=plt.cm.jet)
            #plt.colorbar()
            plt.title('Image: {}'.format(similar_image_paths[i]))

            #plt.tight_layout()
        plt.suptitle('Overall Title')
        plt.show()

# %%
num_images  = len(filenames)

# %%
import random

for i in range(2):
    random_image_index = i
    print(random_image_index)
    distances, indices = neighbors.kneighbors([feature_list[random_image_index]],n_neighbors=5)
    # don't take the first closest image as it will be the same image
    similar_image_paths = [filenames[random_image_index]] +[filenames[indices[0][i]] for i in range(1,4)]
    print(similar_image_paths)
    print(distances[0])
    plot_images(similar_image_paths, distances[0])
# Out:
# 0
# ['google_image_search/mslogo1.jpeg', 'google_image_search/mslogo2.png', 'google_image_search/mslogo4.jpeg', 'google_image_search/mslogo1_180degree_rotation copy.jpeg']
# [6.1439060e-08 6.7026287e-01 7.9184866e-01 8.4925073e-01 9.7421110e-01]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-101-7c0c046a9104> in <module>
#       9     print(similar_image_paths)
#      10     print(distances[0])
# ---> 11     plot_images(similar_image_paths, distances[0])
#
# <ipython-input-99-8d11008512f5> in plot_images(similar_image_paths, distances)
#       4         for i, ax in enumerate(axs.flatten()):
#       5             plt.sca(ax)
# ----> 6             plt.imshow(mpimg.imread(similar_image_paths[i]), cmap=plt.cm.jet)
#       7             #plt.colorbar()
#       8             plt.title('Image: {}'.format(similar_image_paths[i]))
#
# IndexError: list index out of range

# %%
len(feature_list)
# Out:
# 11

# %%
axs
# Out:
# array([<AxesSubplot:title={'center':'Image: 1'}>,
#        <AxesSubplot:title={'center':'Image: 2'}>,
#        <AxesSubplot:title={'center':'Image: 3'}>], dtype=object)

# %% [markdown]
# ## Different aspects of image similarity
# - shapes inside logo
# - 0 to 360 degree rotation
# - mirroring
# - text ka font ,size change ho
# - trade dress: color scheme,text arrangement,font size

# %% [markdown]
# ### Histogram Intersection Algorithm

# %% [markdown]
# #### It will work well only when we can remove background from images(My assumption)
# #### So possibly extract objects and then run histogram intersection algorithm
# #### Research paper : http://stephenwestland.co.uk/pdf/lee_xin_westland_CR&A_2005.pdf

# %%
## using deepgaze library
# !git clone https://github.com/mpatacchiola/deepgaze.git
# Out:
# Cloning into 'deepgaze'...
# remote: Enumerating objects: 1324, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 1324 (delta 41), reused 53 (delta 20), pack-reused 1235
# Receiving objects: 100% (1324/1324), 239.18 MiB | 10.44 MiB/s, done.
# Resolving deltas: 100% (722/722), done.
# Updating files: 100% (170/170), done.

# %%
# !cd deepgaze/ && git checkout 2.0 && python3 setup.py install
# Out:
# Already on '2.0'
# Your branch is up to date with 'origin/2.0'.
# /Users/Rahulthakur/opt/anaconda3/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'include_package_data'
#   warnings.warn(msg)
# running install
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/deepgaze
# copying deepgaze/load_model.py -> build/lib/deepgaze
# copying deepgaze/haar_cascade.py -> build/lib/deepgaze
# copying deepgaze/cnn_head_pose_estimator.py -> build/lib/deepgaze
# copying deepgaze/bayes_filter.py -> build/lib/deepgaze
# copying deepgaze/saliency_map.py -> build/lib/deepgaze
# copying deepgaze/__init__.py -> build/lib/deepgaze
# copying deepgaze/color_classification.py -> build/lib/deepgaze
# copying deepgaze/face_landmark_detection.py -> build/lib/deepgaze
# copying deepgaze/head_pose_estimation.py -> build/lib/deepgaze
# copying deepgaze/face_detection.py -> build/lib/deepgaze
# copying deepgaze/motion_detection.py -> build/lib/deepgaze
# copying deepgaze/color_detection.py -> build/lib/deepgaze
# copying deepgaze/mask_analysis.py -> build/lib/deepgaze
# copying deepgaze/motion_tracking.py -> build/lib/deepgaze
# running install_lib
# creating /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/load_model.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/haar_cascade.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/cnn_head_pose_estimator.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/bayes_filter.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/saliency_map.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/__init__.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/color_classification.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/face_landmark_detection.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/head_pose_estimation.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/face_detection.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/motion_detection.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/color_detection.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/mask_analysis.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# copying build/lib/deepgaze/motion_tracking.py -> /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/load_model.py to load_model.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/haar_cascade.py to haar_cascade.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/cnn_head_pose_estimator.py to cnn_head_pose_estimator.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/bayes_filter.py to bayes_filter.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/saliency_map.py to saliency_map.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/__init__.py to __init__.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/color_classification.py to color_classification.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/face_landmark_detection.py to face_landmark_detection.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/head_pose_estimation.py to head_pose_estimation.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/face_detection.py to face_detection.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/motion_detection.py to motion_detection.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/color_detection.py to color_detection.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/mask_analysis.py to mask_analysis.cpython-38.pyc
# byte-compiling /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze/motion_tracking.py to motion_tracking.cpython-38.pyc
# running install_egg_info
# Writing /Users/Rahulthakur/opt/anaconda3/lib/python3.8/site-packages/deepgaze-0.1-py3.8.egg-info

# %%
histogram_classifier = HistogramColorClassifier(channels=[0, 1, 2], 
                                         hist_size=[128, 128, 128], 
                                         hist_range=[0, 256, 0, 256, 0, 256], 
                                         hist_type='BGR')
def histogram_intersection(target_image,image_list):
    """
    Returns the list of images and their similarity from target image
    
    """
    histogram_classifier = HistogramColorClassifier(channels=[0, 1, 2], 
                                         hist_size=[128, 128, 128], 
                                         hist_range=[0, 256, 0, 256, 0, 256], 
                                         hist_type='BGR')
    
    for image in image_list:
        print(image)
        image_model = cv2.imread(image)
        plt.imshow(mpimg.image_model)
        
        print(image_model.shape)
        image_model_2 = cv2.resize(image_model, (224,224))
        print(image_model_2.shape)
        histogram_classifier.addModelHistogram(image_model_2)
        
    comparison_array = histogram_classifier.returnHistogramComparisonArray(image, 
                                                                method="intersection")
    
    return dict(zip(image_list,list(comparison_array)))

# %%
histogram_intersection(filenames[2],filenames[:5])
# Out:
# google_image_search/hathway1.png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-255-3fd85df0aee8> in <module>
# ----> 1 histogram_intersection(filenames[2],filenames[:5])
#
# <ipython-input-254-e5c01d127cfd> in histogram_intersection(target_image, image_list)
#      16         print(image)
#      17         image_model = cv2.imread(image)
# ---> 18         plt.imshow(mpimg.image_model)
#      19
#      20         print(image_model.shape)
#
# AttributeError: module 'matplotlib.image' has no attribute 'image_model'

# %%
import cv2
import numpy as np
from deepgaze.color_classification import HistogramColorClassifier

my_classifier = HistogramColorClassifier(channels=[0, 1, 2], 
                                         hist_size=[128, 128, 128], 
                                         hist_range=[0, 256, 0, 256, 0, 256], 
                                         hist_type='BGR')

# %%
image_list = [filenames[0],filenames[1],filenames[2],filenames[3],filenames[4]]
## filenames[3],filenames[4],filenames[5],filenames[7],filenames[13]
base_file = filenames[2]

# %%
model_1 = cv2.imread(filenames[0]) 
my_classifier.addModelHistogram(model_1)

model_2 = cv2.imread(filenames[1]) 
my_classifier.addModelHistogram(model_2)

model_3 = cv2.imread(filenames[2]) 
my_classifier.addModelHistogram(model_3)

model_4 = cv2.imread(filenames[3]) 
my_classifier.addModelHistogram(model_4)

model_5 = cv2.imread(filenames[4]) 
my_classifier.addModelHistogram(model_5)

# model_6 = cv2.imread(filenames[3]) 
# model_7 = cv2.imread(filenames[4])
# model_8 = cv2.imread(filenames[5]) 
# model_9 = cv2.imread(filenames[7])
# model_10 = cv2.imread(filenames[13])

# my_classifier.addModelHistogram(model_6)
# my_classifier.addModelHistogram(model_7)
# my_classifier.addModelHistogram(model_8)
# my_classifier.addModelHistogram(model_9)
# my_classifier.addModelHistogram(model_10)

# %%
image = cv2.imread(filenames[2])
comparison_array = my_classifier.returnHistogramComparisonArray(image, 
                                                                method="intersection")

# %%
list(comparison_array)
# Out:
# [8.556703687645495e-05, 0.0, 1.1478265638124867, 0.0, 0.0]

# %%
probability_array = comparison_array / np.sum(comparison_array)

# %%
probability_array
# Out:
# array([7.45414519e-05, 0.00000000e+00, 9.99925459e-01, 0.00000000e+00,
#        0.00000000e+00])

# %%
plt.imshow(mpimg.imread(filenames[2]))

# %%
import matplotlib.pyplot as plt

# %%
def display_image(image_name,i):
#     plt.imshow(mpimg.imread(image_name))
#     image = mpimg.imread(image_name)
#     # <something gets done here>
    plt.figure()
    plt.title('{} {}'.format(image_name,probability_array[i]))
    plt.imshow(mpimg.imread(image_name))

# %%
for i,image_name in enumerate(image_list):
    print(i,image_name)        
    display_image(image_name,i)
# Out:
# 0 google_image_search/hathway1.png
# 1 google_image_search/hathway2.png
# 2 google_image_search/hathway7.jpeg
# 3 google_image_search/xbox9.png
# 4 google_image_search/hero6.png
